# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('abalone.csv')

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.isna().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df.Rings.unique()
# Out:
# array([15,  7,  9, 10,  8, 20, 16, 19, 14, 11, 12, 18, 13,  5,  4,  6, 21,
#        17, 22,  1,  3, 26, 23, 29,  2, 27, 25, 24])

# %%
df['Sex'].value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %% [markdown]
# # Discriptive Statistics

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
np.where(df['Height']==0)
# Out:
# (array([1257, 3996]),)

# %%
df.loc[1257]
# Out:
# Sex                    I
# Length              0.43
# Diameter            0.34
# Height               0.0
# Whole weight       0.428
# Shucked weight    0.2065
# Viscera weight     0.086
# Shell weight       0.115
# Rings                  8
# Name: 1257, dtype: object

# %%
df.loc[3996]
# Out:
# Sex                    I
# Length             0.315
# Diameter            0.23
# Height               0.0
# Whole weight       0.134
# Shucked weight    0.0575
# Viscera weight    0.0285
# Shell weight      0.3505
# Rings                  6
# Name: 3996, dtype: object

# %% [markdown]
# ## According to observation if length and diameter is given how can be height will be 0.So dropping two indexes

# %%
df=df.drop([1257,3996],axis=0)

# %%
df.shape
# Out:
# (4175, 9)

# %% [markdown]
# # EDA

# %% [markdown]
# ### Univariate Analysis

# %%
sns.distplot(df['Length'])
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %%
sns.distplot(df['Diameter'])
# Out:
# /home/ankurkumar7796/.local/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Diameter', ylabel='Density'>

# %%
sns.distplot(df['Height'])
# Out:
# /home/ankurkumar7796/.local/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
sns.distplot(df['Whole weight'])
# Out:
# /home/ankurkumar7796/.local/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Whole weight', ylabel='Density'>

# %%
sns.distplot(df['Shucked weight'])
# Out:
# /home/ankurkumar7796/.local/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Shucked weight', ylabel='Density'>

# %%
sns.distplot(df['Viscera weight'])
# Out:
# /home/ankurkumar7796/.local/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Viscera weight', ylabel='Density'>

# %%
sns.distplot(df['Shell weight'])
# Out:
# /home/ankurkumar7796/.local/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Shell weight', ylabel='Density'>

# %%
plt.figure(figsize=(10,12))
plt.pie(df['Sex'].value_counts(),labels=df.Sex.unique(),autopct='%1.1f%%',shadow=True)
plt.legend()
plt.show()

# %%
sns.distplot(df['Rings'])
# Out:
# /home/ankurkumar7796/.local/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Rings', ylabel='Density'>

# %% [markdown]
# ## Observations: It seems skewness in most of the features,also in plot we can see clearly that weights having some negative value

# %%
plt.figure(figsize=(10,15))
plotnumber=1
for column in df[['Length','Diameter','Height','Whole weight','Shucked weight','Viscera weight','Shell weight']]:
    if plotnumber <= 9:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(df[column])
        
    plotnumber=plotnumber+1
plt.show()
# Out:
# /home/ankurkumar7796/.local/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/ankurkumar7796/.local/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/ankurkumar7796/.local/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %% [markdown]
# ### observation: We can find the outlier through the box plot.So we have to work to remove outliers

# %%
df.skew()
# Out:
# /home/ankurkumar7796/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Length           -0.640993
# Diameter         -0.610182
# Height            3.166364
# Whole weight      0.530549
# Shucked weight    0.718735
# Viscera weight    0.591455
# Shell weight      0.621081
# Rings             1.113754
# dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df['Sex']=lb.fit_transform(df['Sex'])

# %%
df.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %%
from scipy.stats import zscore

# %%
df=df[(np.abs(zscore(df))<3).all(axis=1)]

# %%
df.shape
# Out:
# (4027, 9)

# %%
plt.figure(figsize=(10,15))
plotnumber=1
for column in df[['Length','Diameter','Height','Whole weight','Shucked weight','Viscera weight','Shell weight']]:
    if plotnumber <= 9:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(df[column])
        
    plotnumber=plotnumber+1
plt.show()
# Out:
# /home/ankurkumar7796/.local/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/ankurkumar7796/.local/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/ankurkumar7796/.local/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
df.skew()
# Out:
# Sex              -0.094886
# Length           -0.623076
# Diameter         -0.598650
# Height           -0.244251
# Whole weight      0.334204
# Shucked weight    0.458295
# Viscera weight    0.437116
# Shell weight      0.349471
# Rings             0.725464
# dtype: float64

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.barplot(x='Sex',y='Rings',data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Rings'>

# %%
sns.barplot(x='Rings',y='Length',data=df)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Length'>

# %% [markdown]
# ### observation :- As the Length increases the Rings also increases

# %%
sns.barplot(x='Rings',y='Diameter',data=df)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Diameter'>

# %% [markdown]
# ### Similarly as the diameter increases the rings increases

# %%
sns.barplot(x='Rings',y='Height',data=df)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Height'>

# %%
sns.barplot(x='Rings',y='Whole weight',data=df)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Whole weight'>

# %%
sns.barplot(x='Rings',y='Shucked weight',data=df)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Shucked weight'>

# %%
sns.barplot(x='Rings',y='Viscera weight',data=df)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Viscera weight'>

# %%
sns.barplot(x='Rings',y='Shell weight',data=df)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Shell weight'>

# %%
plt.figure(figsize=(10,15))
plotnumber=1
for column in df:
    if plotnumber <= 9:
        ax=plt.subplot(3,3,plotnumber)
        sns.scatterplot(df[column],y='Rings',data=df)
        
    plotnumber=plotnumber+1
plt.show()
# Out:
# /home/ankurkumar7796/.local/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/ankurkumar7796/.local/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/ankurkumar7796/.local/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %% [markdown]
# # Observation: The features showing the trend is the increase in value increases rings

# %%
## Lets check correlation
corr=df.corr()

# %%
corr
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.043639 -0.046531 -0.046282     -0.034776
# Length         -0.043639  1.000000  0.986011  0.895432      0.934410
# Diameter       -0.046531  0.986011  1.000000  0.901803      0.934069
# Height         -0.046282  0.895432  0.901803  1.000000      0.891783
# Whole weight   -0.034776  0.934410  0.934069  0.891783      1.000000
# Shucked weight -0.016457  0.909245  0.904302  0.843010      0.971024
# Viscera weight -0.045292  0.907957  0.904192  0.869273      0.966612
# Shell weight   -0.043825  0.914518  0.921779  0.899716      0.961216
# Rings          -0.033272  0.567074  0.584978  0.612540      0.548295
#
#                 Shucked weight  Viscera weight  Shell weight     Rings
# Sex                  -0.016457       -0.045292     -0.043825 -0.033272
# Length                0.909245        0.907957      0.914518  0.567074
# ...

# %%
plt.figure(figsize=(12,12))
sns.heatmap(corr,annot=True,annot_kws={'size':10})
plt.show()

# %%
df.drop('Rings',axis=1).corrwith(df.Rings).plot(kind='bar',figsize=(10,7),title='Correlation with Rings')
# Out:
# <AxesSubplot:title={'center':'Correlation with Rings'}>

# %% [markdown]
# ### Observation:- from the above heatmap it is visible that length and diameter are strongly correlated

# %%
from sklearn.preprocessing import StandardScaler

# %%
X=df.drop(columns=['Rings','Length'],axis=1)
y=df.Rings

# %%
scaler=StandardScaler()

# %%
x_scaled=scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.30,random_state=41)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
ypred=lr.predict(x_train)

# %%
r2_score(y_train,ypred)
# Out:
# 0.506904026067703

# %%
y_pred=lr.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.5281945897704969

# %%
from sklearn.linear_model import Ridge, RidgeCV, Lasso,LassoCV

# %%
## Lets check through L1 and L2 regularization

# %%
ridge=RidgeCV(alphas=[0.0001])

# %%
ridge.fit(x_train,y_train)
# Out:
# RidgeCV(alphas=array([0.0001]))

# %%
ypred=ridge.predict(x_train)

# %%
r2_score(y_train,ypred)
# Out:
# 0.5069040260670314

# %%
y_pred=ridge.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.5281946913350154

# %%
print(mean_squared_error(y_test,y_pred))
# Out:
# 3.735296677171211

# %%
print(mean_absolute_error(y_test,y_pred))
# Out:
# 1.4382133158149

# %%
from sklearn.svm import SVR

# %%
sv=SVR()

# %%
sv.fit(x_train,y_train)
# Out:
# SVR()

# %%
ypred=sv.predict(x_train)

# %%
r2_score(y_train,ypred)
# Out:
# 0.5427014569815649

# %%
y_pred=sv.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.5501682250989013

# %% [markdown]
# # SAVING THE MODEL

# %%
import pickle

# %%
filename="Abalone"
pickle.dump(sv,open(filename,'wb'))
